# %% [markdown]
# <a href="https://colab.research.google.com/github/rhazem13/MemoryMate/blob/master/Alzheimers_Detection_using_DenseNet169_DeepLearing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **IMPORT** **LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# **IMPORT / VIEWING / PREPROCESSING DATASET**

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 128)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 128)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Demetia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [04:43<00:00, 56.71s/it]

# %% [markdown]
# **MODEL** **BUILDING**

# %%
# Model Initialization

base_model = DenseNet169(input_shape=(224,224,3), 
                         include_top=False,
                         weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 3s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 7, 7, 1664)        12642880
#
#  dropout (Dropout)           (None, 7, 7, 1664)        0
#
#  flatten (Flatten)           (None, 81536)             0
#
#  batch_normalization (BatchN  (None, 81536)            326144
#  ormalization)
#
#  dense (Dense)               (None, 2048)              166987776
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  activation (Activation)     (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 182,071,364
# Trainable params: 169,259,268
# Non-trainable params: 12,812,096
# _________________________________________________________________

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)

# %%
# Defining Callbacks

filepath = '/content/drive/MyDrive/Colab Notebooks/best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
# !nvidia-smi
# Out:
# Thu Feb  2 05:01:27 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   78C    P0    34W /  70W |   9142MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     10779      C                                    9139MiB |
# +-----------------------------------------------------------------------------+

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 500,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4792 - auc: 0.9575
# Epoch 1: val_auc did not improve from 0.86896
# 33/33 [==============================] - 55s 2s/step - loss: 0.4792 - auc: 0.9575 - val_loss: 1.1039 - val_auc: 0.8577
# Epoch 2/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5139 - auc: 0.9533
# Epoch 2: val_auc did not improve from 0.86896
# 33/33 [==============================] - 54s 2s/step - loss: 0.5139 - auc: 0.9533 - val_loss: 1.2477 - val_auc: 0.8569
# Epoch 3/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4614 - auc: 0.9609
# Epoch 3: val_auc did not improve from 0.86896
# 33/33 [==============================] - 55s 2s/step - loss: 0.4614 - auc: 0.9609 - val_loss: 1.2368 - val_auc: 0.8484
# Epoch 4/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4310 - auc: 0.9658
# Epoch 4: val_auc did not improve from 0.86896
# 33/33 [==============================] - 54s 2s/step - loss: 0.4310 - auc: 0.9658 - val_loss: 1.2730 - val_auc: 0.8480
# Epoch 5/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4443 - auc: 0.9637
# Epoch 5: val_auc did not improve from 0.86896
# 33/33 [==============================] - 54s 2s/step - loss: 0.4443 - auc: 0.9637 - val_loss: 1.3643 - val_auc: 0.8382
# Epoch 6/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4572 - auc: 0.9616
# Epoch 6: val_auc did not improve from 0.86896
# 33/33 [==============================] - 53s 2s/step - loss: 0.4572 - auc: 0.9616 - val_loss: 1.0987 - val_auc: 0.8676
# Epoch 7/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4515 - auc: 0.9624
# Epoch 7: val_auc did not improve from 0.86896
# 33/33 [==============================] - 55s 2s/step - loss: 0.4515 - auc: 0.9624 - val_loss: 1.1713 - val_auc: 0.8566
# Epoch 8/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4370 - auc: 0.9647
# Epoch 8: val_auc did not improve from 0.86896
# 33/33 [==============================] - 54s 2s/step - loss: 0.4370 - auc: 0.9647 - val_loss: 1.1055 - val_auc: 0.8643
# Epoch 9/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4416 - auc: 0.9639
# Epoch 9: val_auc did not improve from 0.86896
# 33/33 [==============================] - 54s 2s/step - loss: 0.4416 - auc: 0.9639 - val_loss: 1.2799 - val_auc: 0.8468
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4258 - auc: 0.9664
# Epoch 10: val_auc did not improve from 0.86896
# 33/33 [==============================] - 54s 2s/step - loss: 0.4258 - auc: 0.9664 - val_loss: 1.1592 - val_auc: 0.8653
# Epoch 11/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4210 - auc: 0.9674
# Epoch 11: val_auc improved from 0.86896 to 0.87404, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 33/33 [==============================] - 71s 2s/step - loss: 0.4210 - auc: 0.9674 - val_loss: 1.0463 - val_auc: 0.8740
# Epoch 12/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4251 - auc: 0.9668
# Epoch 12: val_auc did not improve from 0.87404
# 33/33 [==============================] - 59s 2s/step - loss: 0.4251 - auc: 0.9668 - val_loss: 1.3201 - val_auc: 0.8453
# Epoch 13/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4314 - auc: 0.9659
# Epoch 13: val_auc did not improve from 0.87404
# 33/33 [==============================] - 53s 2s/step - loss: 0.4314 - auc: 0.9659 - val_loss: 1.0978 - val_auc: 0.8707
# Epoch 14/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4230 - auc: 0.9668
# Epoch 14: val_auc did not improve from 0.87404
# 33/33 [==============================] - 54s 2s/step - loss: 0.4230 - auc: 0.9668 - val_loss: 1.0982 - val_auc: 0.8734
# Epoch 15/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4312 - auc: 0.9656
# Epoch 15: val_auc improved from 0.87404 to 0.88159, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 33/33 [==============================] - 73s 2s/step - loss: 0.4312 - auc: 0.9656 - val_loss: 0.9744 - val_auc: 0.8816
# Epoch 16/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4076 - auc: 0.9692
# Epoch 16: val_auc did not improve from 0.88159
# 33/33 [==============================] - 59s 2s/step - loss: 0.4076 - auc: 0.9692 - val_loss: 0.9827 - val_auc: 0.8778
# Epoch 17/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4462 - auc: 0.9632
# Epoch 17: val_auc did not improve from 0.88159
# 33/33 [==============================] - 54s 2s/step - loss: 0.4462 - auc: 0.9632 - val_loss: 1.0395 - val_auc: 0.8765
# Epoch 18/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4237 - auc: 0.9667
# Epoch 18: val_auc improved from 0.88159 to 0.89216, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 33/33 [==============================] - 72s 2s/step - loss: 0.4237 - auc: 0.9667 - val_loss: 0.9252 - val_auc: 0.8922
# Epoch 19/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4031 - auc: 0.9696
# Epoch 19: val_auc did not improve from 0.89216
# 33/33 [==============================] - 60s 2s/step - loss: 0.4031 - auc: 0.9696 - val_loss: 0.9554 - val_auc: 0.8854
# Epoch 20/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4045 - auc: 0.9694
# Epoch 20: val_auc did not improve from 0.89216
# 33/33 [==============================] - 55s 2s/step - loss: 0.4045 - auc: 0.9694 - val_loss: 1.1264 - val_auc: 0.8643
# Epoch 21/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3860 - auc: 0.9720
# Epoch 21: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.3860 - auc: 0.9720 - val_loss: 1.1541 - val_auc: 0.8649
# Epoch 22/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3852 - auc: 0.9725
# Epoch 22: val_auc did not improve from 0.89216
# 33/33 [==============================] - 55s 2s/step - loss: 0.3852 - auc: 0.9725 - val_loss: 1.1739 - val_auc: 0.8642
# Epoch 23/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3930 - auc: 0.9711
# Epoch 23: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.3930 - auc: 0.9711 - val_loss: 1.1806 - val_auc: 0.8618
# Epoch 24/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4113 - auc: 0.9688
# Epoch 24: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.4113 - auc: 0.9688 - val_loss: 1.1961 - val_auc: 0.8629
# Epoch 25/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3890 - auc: 0.9714
# Epoch 25: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.3890 - auc: 0.9714 - val_loss: 1.1409 - val_auc: 0.8637
# Epoch 26/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3958 - auc: 0.9709
# Epoch 26: val_auc did not improve from 0.89216
# 33/33 [==============================] - 55s 2s/step - loss: 0.3958 - auc: 0.9709 - val_loss: 1.2821 - val_auc: 0.8484
# Epoch 27/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3992 - auc: 0.9705
# Epoch 27: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.3992 - auc: 0.9705 - val_loss: 1.0844 - val_auc: 0.8735
# Epoch 28/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4286 - auc: 0.9660
# Epoch 28: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.4286 - auc: 0.9660 - val_loss: 1.3572 - val_auc: 0.8419
# Epoch 29/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4138 - auc: 0.9689
# Epoch 29: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.4138 - auc: 0.9689 - val_loss: 1.1316 - val_auc: 0.8669
# Epoch 30/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3967 - auc: 0.9707
# Epoch 30: val_auc did not improve from 0.89216
# 33/33 [==============================] - 55s 2s/step - loss: 0.3967 - auc: 0.9707 - val_loss: 1.1962 - val_auc: 0.8675
# Epoch 31/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3672 - auc: 0.9748
# Epoch 31: val_auc did not improve from 0.89216
# 33/33 [==============================] - 53s 2s/step - loss: 0.3672 - auc: 0.9748 - val_loss: 1.2159 - val_auc: 0.8610
# Epoch 32/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3857 - auc: 0.9723
# Epoch 32: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.3857 - auc: 0.9723 - val_loss: 1.1874 - val_auc: 0.8653
# Epoch 33/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3827 - auc: 0.9728
# Epoch 33: val_auc did not improve from 0.89216
# 33/33 [==============================] - 54s 2s/step - loss: 0.3827 - auc: 0.9728 - val_loss: 1.1874 - val_auc: 0.8676
# Epoch 33: early stopping

# %% [markdown]
# **MODEL EVALUATION**

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
 #Test Data 

test_dataset  = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/test',
                                                 target_size = (224,224),
                                                 class_mode = 'categorical',
                                                 batch_size = 128)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
# Evaluating Loss and AUC

model.evaluate(test_dataset)
# Out:
# 10/10 [==============================] - 5s 460ms/step - loss: 1.2922 - auc: 0.8774
# [1.292241096496582, 0.8774380683898926]

# %%
from numpy import array

# %%
# Test Case 1: Non-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/test/NonDemented/26 (100).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
probability = round(np.max(model.predict(img)*100),2)

print(probability, '% chances are there that the image is' , idc[np.argmax(model.predict(img))])
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 99.91 % chances are there that the image is NonDemented

# %%
# Test Case 2: Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/test/MildDemented/26 (19).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
probability = round(np.max(model.predict(img)*100),2)

print(probability, '% chances are there that the image is' , idc[np.argmax(model.predict(img))])
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 92.19 % chances are there that the image is MildDemented

# %%
# Test Case 3: Moderate Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/test/ModerateDemented/27 (2).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
probability = round(np.max(model.predict(img)*100),2)

print(probability, '% chances are there that the image is' , idc[np.argmax(model.predict(img))])
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 34ms/step
# 98.28 % chances are there that the image is ModerateDemented

# %%
# Test Case 4: Very Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/test/VeryMildDemented/26 (55).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict(img)
probability = round(np.max(model.predict(img)*100),2)
print(probability, '% chances are there that the image is' , idc[np.argmax(model.predict(img))])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 95.29 % chances are there that the image is VeryMildDemented
